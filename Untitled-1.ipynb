# %%
# !pip install langchain-community

# %%
import random 
from typing import TypedDict,List,Dict,Union ,Annotated,Sequence
from langgraph.graph import StateGraph,START,END
from langchain_core.messages import BaseMessage
from langchain_core.messages import ToolMessage
from langchain_core.messages import SystemMessage
from langchain_core.tools import tool
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode
from langchain_community.chat_models import ChatOllama
from langchain_core.messages import HumanMessage , AIMessage
llm = ChatOllama(model="phi3")

# %%
class AgentState(TypedDict):
   messages: List[Union[HumanMessage,AIMessage]]

# %%
def process(state:AgentState)-> AgentState:
    response=llm.invoke(state["messages"])
    state["messages"].append(AIMessage(content=response.content))
    print(f"\nAI: {response.content}")
    print("current state ", state["messages"])
    return state

# %%
graph=StateGraph(AgentState)
graph.add_node("process",process)
graph.add_edge("process",END)
graph.add_edge(START,"process") 




app=graph.compile()

# %%
from IPython.display import Image,display
display(Image(app.get_graph().draw_mermaid_png()))
# Out:
# Running cells with 'venv (Python 3.9.6)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/youssefrezk/Desktop/bachelor_project/venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
conversation_history=[]
user_input =input("enter : ")
while user_input!="exit":
    conversation_history.append(HumanMessage(content=user_input))
    result=app.invoke({"messages":conversation_history})
    print(result["messages"])
    conversation_history=result["messages"]
    user_input =input("enter : ")

with open("logging.txt", "w") as file :
    file.write("Your Conversation Log:\n")
    for messages in conversation_history:
        if isinstance(messages,HumanMessage):
            file.write(f"You:{messages.content}\n")
        elif isinstance(messages, AIMessage):
            file.write(f"AI:{messages.content}\n\n")
    file.write("end of converstion")
# Out:
# AI: Hello! How can I help you today? If there'selly anything specific in mind, feel free to ask. Remember that my purpose is to assist with information and general guidance within the scope of our conversation. Let me know if there are any questions or topics you’re curious about.
# current state  [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello! How can I help you today? If there'selly anything specific in mind, feel free to ask. Remember that my purpose is to assist with information and general guidance within the scope of our conversation. Let me know if there are any questions or topics you’re curious about.", additional_kwargs={}, response_metadata={})]
# [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello! How can I help you today? If there'selly anything specific in mind, feel free to ask. Remember that my purpose is to assist with information and general guidance within the scope of our conversation. Let me know if there are any questions or topics you’re curious about.", additional_kwargs={}, response_metadata={})]
#
# AI: Nice to meet you too! It seems like your name has an interesting origin—it's actually a Māori term meaning "bush." If I might ask, what brings you here today? Is there something specific related to this cultural reference that caught your attention or interest in learning more about it?
# current state  [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello! How can I help you today? If there'selly anything specific in mind, feel free to ask. Remember that my purpose is to assist with information and general guidance within the scope of our conversation. Let me know if there are any questions or topics you’re curious about.", additional_kwargs={}, response_metadata={}), HumanMessage(content='i am ruru', additional_kwargs={}, response_metadata={}), AIMessage(content='Nice to meet you too! It seems like your name has an interesting origin—it\'s actually a Māori term meaning "bush." If I might ask, what brings you here today? Is there something specific related to this cultural reference that caught your attention or interest in learning more about it?', additional_kwargs={}, response_metadata={})]
# [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello! How can I help you today? If there'selly anything specific in mind, feel free to ask. Remember that my purpose is to assist with information and general guidance within the scope of our conversation. Let me know if there are any questions or topics you’re curious about.", additional_kwargs={}, response_metadata={}), HumanMessage(content='i am ruru', additional_kwargs={}, response_metadata={}), AIMessage(content='Nice to meet you too! It seems like your name has an interesting origin—it\'s actually a Māori term meaning "bush." If I might ask, what brings you here today? Is there something specific related to this cultural reference that caught your attention or interest in learning more about it?', additional_kwargs={}, response_metadata={})]
#
# AI: Good morning! It’s always great meeting someone new. As the sun rises and greets us with light anew, I hope you are having a day full of positivity and purposeful actions. If there's anything on your mind about life or just some casual conversation to share in this beautiful start of our journey together today, feel free to let me know!
# current state  [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello! How can I help you today? If there'selly anything specific in mind, feel free to ask. Remember that my purpose is to assist with information and general guidance within the scope of our conversation. Let me know if there are any questions or topics you’re curious about.", additional_kwargs={}, response_metadata={}), HumanMessage(content='i am ruru', additional_kwargs={}, response_metadata={}), AIMessage(content='Nice to meet you too! It seems like your name has an interesting origin—it\'s actually a Māori term meaning "bush." If I might ask, what brings you here today? Is there something specific related to this cultural reference that caught your attention or interest in learning more about it?', additional_kwargs={}, response_metadata={}), HumanMessage(content='good morning', additional_kwargs={}, response_metadata={}), AIMessage(content="Good morning! It’s always great meeting someone new. As the sun rises and greets us with light anew, I hope you are having a day full of positivity and purposeful actions. If there's anything on your mind about life or just some casual conversation to share in this beautiful start of our journey together today, feel free to let me know!", additional_kwargs={}, response_metadata={})]
# [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello! How can I help you today? If there'selly anything specific in mind, feel free to ask. Remember that my purpose is to assist with information and general guidance within the scope of our conversation. Let me know if there are any questions or topics you’re curious about.", additional_kwargs={}, response_metadata={}), HumanMessage(content='i am ruru', additional_kwargs={}, response_metadata={}), AIMessage(content='Nice to meet you too! It seems like your name has an interesting origin—it\'s actually a Māori term meaning "bush." If I might ask, what brings you here today? Is there something specific related to this cultural reference that caught your attention or interest in learning more about it?', additional_kwargs={}, response_metadata={}), HumanMessage(content='good morning', additional_kwargs={}, response_metadata={}), AIMessage(content="Good morning! It’s always great meeting someone new. As the sun rises and greets us with light anew, I hope you are having a day full of positivity and purposeful actions. If there's anything on your mind about life or just some casual conversation to share in this beautiful start of our journey together today, feel free to let me know!", additional_kwargs={}, response_metadata={})]
#
# AI: Of course! Why don't scientists trust atoms? Because they make up everything—even though the jokes about them might sometimes be just molecules off. Enjoy your day with laughter and light-hearted moments wherever you go, Ruru! If there’s more I can do to brighten your morning or help in any other way, please don't hesitate to let me know.
# current state  [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello! How can I help you today? If there'selly anything specific in mind, feel free to ask. Remember that my purpose is to assist with information and general guidance within the scope of our conversation. Let me know if there are any questions or topics you’re curious about.", additional_kwargs={}, response_metadata={}), HumanMessage(content='i am ruru', additional_kwargs={}, response_metadata={}), AIMessage(content='Nice to meet you too! It seems like your name has an interesting origin—it\'s actually a Māori term meaning "bush." If I might ask, what brings you here today? Is there something specific related to this cultural reference that caught your attention or interest in learning more about it?', additional_kwargs={}, response_metadata={}), HumanMessage(content='good morning', additional_kwargs={}, response_metadata={}), AIMessage(content="Good morning! It’s always great meeting someone new. As the sun rises and greets us with light anew, I hope you are having a day full of positivity and purposeful actions. If there's anything on your mind about life or just some casual conversation to share in this beautiful start of our journey together today, feel free to let me know!", additional_kwargs={}, response_metadata={}), HumanMessage(content='tell me a joke ', additional_kwargs={}, response_metadata={}), AIMessage(content="Of course! Why don't scientists trust atoms? Because they make up everything—even though the jokes about them might sometimes be just molecules off. Enjoy your day with laughter and light-hearted moments wherever you go, Ruru! If there’s more I can do to brighten your morning or help in any other way, please don't hesitate to let me know.", additional_kwargs={}, response_metadata={})]
# [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content="Hello! How can I help you today? If there'selly anything specific in mind, feel free to ask. Remember that my purpose is to assist with information and general guidance within the scope of our conversation. Let me know if there are any questions or topics you’re curious about.", additional_kwargs={}, response_metadata={}), HumanMessage(content='i am ruru', additional_kwargs={}, response_metadata={}), AIMessage(content='Nice to meet you too! It seems like your name has an interesting origin—it\'s actually a Māori term meaning "bush." If I might ask, what brings you here today? Is there something specific related to this cultural reference that caught your attention or interest in learning more about it?', additional_kwargs={}, response_metadata={}), HumanMessage(content='good morning', additional_kwargs={}, response_metadata={}), AIMessage(content="Good morning! It’s always great meeting someone new. As the sun rises and greets us with light anew, I hope you are having a day full of positivity and purposeful actions. If there's anything on your mind about life or just some casual conversation to share in this beautiful start of our journey together today, feel free to let me know!", additional_kwargs={}, response_metadata={}), HumanMessage(content='tell me a joke ', additional_kwargs={}, response_metadata={}), AIMessage(content="Of course! Why don't scientists trust atoms? Because they make up everything—even though the jokes about them might sometimes be just molecules off. Enjoy your day with laughter and light-hearted moments wherever you go, Ruru! If there’s more I can do to brighten your morning or help in any other way, please don't hesitate to let me know.", additional_kwargs={}, response_metadata={})]
