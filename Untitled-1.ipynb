# %%
from dotenv import load_dotenv

# %%
import os

# %%
load_dotenv()
# Out:
# True

# %%
api_key=os.getenv("OPENAI_API_KEY")
api_key

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3")

response = llm.invoke("Explain semaphores simply")
print(response.content)
# Out:
# Semaphores! A fundamental concept in computer science that can be a bit tricky to grasp at first. But don't worry, I'm here to break it down in simple terms.
#
# **What is a semaphore?**
#
# A semaphore is a variable that controls access to a shared resource or critical section of code. It's like a traffic light for threads (or processes) trying to access the same resource.
#
# Imagine you have a busy coffee shop with multiple lines of people waiting to order. To manage the chaos, you use a system where only one person can enter the ordering area at a time. The "semaphore" is like a virtual sign that says "occupied" when someone is inside and "vacant" when no one is.
#
# **How do semaphores work?**
#
# Here's a simple example:
#
# 1. When a thread wants to access a shared resource (like printing a document), it sends a request to the semaphore.
# ...
